# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv(r'C:\Users\ADMIN\Desktop\dataset.csv')

# %%
df
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv  term_months  int_rate  \
# 0     1474286      30000        30000            30000           36     22.35
# 1     1474287      40000        40000            40000           60     16.14
# 2     1474288      20000        20000            20000           36      7.56
# 3     1474289       4500         4500             4500           36     11.31
# 4     1474290       8425         8425             8425           36     27.27
# ...       ...        ...          ...              ...          ...       ...
# 7058  1482101      24000        24000            24000           60     17.99
# 7059  1482102       7000         7000             7000           36     22.39
# 7060  1482103      30000        30000            30000           60     18.99
# 7061  1482104      35000        35000            35000           36     17.99
# 7062  1482105      20000        20000            19950           36     13.99
#
# ...

# %%
X=df.drop(["loan_status"],axis=1)
Y=df["loan_status"]

# %%
X=df.drop(["last_credit_pull_d"],axis=1)

# %%
X
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv  term_months  int_rate  \
# 0     1474286      30000        30000            30000           36     22.35
# 1     1474287      40000        40000            40000           60     16.14
# 2     1474288      20000        20000            20000           36      7.56
# 3     1474289       4500         4500             4500           36     11.31
# 4     1474290       8425         8425             8425           36     27.27
# ...       ...        ...          ...              ...          ...       ...
# 7058  1482101      24000        24000            24000           60     17.99
# 7059  1482102       7000         7000             7000           36     22.39
# 7060  1482103      30000        30000            30000           60     18.99
# 7061  1482104      35000        35000            35000           36     17.99
# 7062  1482105      20000        20000            19950           36     13.99
#
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7058    1
# 7059    1
# 7060    1
# 7061    1
# 7062    1
# Name: loan_status, Length: 7063, dtype: int64

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.29,random_state=9)

# %%
X
# Out:
#            id  loan_amnt  funded_amnt  funded_amnt_inv  term_months  int_rate  \
# 0     1474286      30000        30000            30000           36     22.35
# 1     1474287      40000        40000            40000           60     16.14
# 2     1474288      20000        20000            20000           36      7.56
# 3     1474289       4500         4500             4500           36     11.31
# 4     1474290       8425         8425             8425           36     27.27
# ...       ...        ...          ...              ...          ...       ...
# 7058  1482101      24000        24000            24000           60     17.99
# 7059  1482102       7000         7000             7000           36     22.39
# 7060  1482103      30000        30000            30000           60     18.99
# 7061  1482104      35000        35000            35000           36     17.99
# 7062  1482105      20000        20000            19950           36     13.99
#
# ...

# %%
Y_train
# Out:
# 5614    1
# 2654    0
# 4230    0
# 3191    0
# 4426    0
#        ..
# 6200    1
# 501     0
# 6782    1
# 4444    0
# 382     0
# Name: loan_status, Length: 5014, dtype: int64

# %%
X_train, X_test, Y_train,Y_test,= train_test_split(X,Y,test_size=0.2, random_state=0)

# %%
X_train= X_train.T
Y_train= Y_train.T
X_test= X_test.T
Y_test= Y_test.T

# %%
X_train
# Out:
#                                  6432       2588       1662       5516  \
# id                          1481414.0  1477160.0  1476115.0  1480376.0
# loan_amnt                      3600.0    35000.0    15600.0    29000.0
# funded_amnt                    3600.0    35000.0    15600.0    29000.0
# funded_amnt_inv                3600.0    35000.0    15600.0    29000.0
# term_months                      36.0       36.0       36.0       60.0
# ...                               ...        ...        ...        ...
# tot_hi_cred_lim               33185.0   105270.0    45321.0    86139.0
# total_bal_ex_mort             29722.0    58553.0    25284.0    67614.0
# total_bc_limit                 2000.0    89800.0     9400.0    38700.0
# total_il_high_credit_limit    31185.0    14170.0    30621.0    47439.0
# disbursement_method               1.0        1.0        1.0        0.0
#
#                                  2608       5824       2364       2933  \
# ...

# %%
Y_train
# Out:
# 6432    1
# 2588    0
# 1662    0
# 5516    1
# 2608    0
#        ..
# 4931    0
# 3264    0
# 1653    0
# 2607    0
# 2732    0
# Name: loan_status, Length: 5650, dtype: int64

# %%
accuracies={}
lr = LogisticRegression()
lr.fit(X_train.T,Y_train.T)
acc= lr.score(X_test.T, Y_test.T)*100
accuracies['Logistic Regression']=acc
print("test accuracy {:.2f}%".format(acc))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-fd235d71239e> in <module>
#       1 accuracies={}
#       2 lr = LogisticRegression()
# ----> 3 lr.fit(X_train.T,Y_train.T)
#       4 acc= lr.score(X_test.T, Y_test.T)*100
#       5 accuracies['Logistic Regression']=acc
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
# ...

# %%
print("RANDOM FOREST")
print("\nConfusion Matrix:")
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(Y_test,Y_head_rf))
print("\n")
print(classification_report(Y_test,Y_head_rf))
print("\nThe Accuracy of Random Forest :")
print(accuracy_score(Y_test, Y_head_rf))
# Out:
# RANDOM FOREST
#
# Confusion Matrix:
# [[1072    0]
#  [   0  341]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1072
#            1       1.00      1.00      1.00       341
#
#     accuracy                           1.00      1413
#    macro avg       1.00      1.00      1.00      1413
# weighted avg       1.00      1.00      1.00      1413
#
#
# The Accuracy of Random Forest :
# 1.0

# %%
from sklearn.metrics import confusion_matrix
cm_lr = confusion_matrix(Y_test,Y_head_lr)
cm_rf = confusion_matrix(Y_test,Y_head_rf)

# %%
plt.figure(figsize=(20,11))
plt.suptitle("Confusion Matrixes",fontsize=24)
plt.subplots_adjust(wspace = 0.8, hspace= 0.4)
plt.subplot(2,3,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(cm_lr,annot=True,cmap="Blues",fmt="d",cbar=False, annot_kws={"size": 24})
plt.subplot(2,3,2)
plt.title("Random Forest Confusion Matrix")
sns.heatmap(cm_rf,annot=True,cmap="Blues",fmt="d",cbar=False, annot_kws={"size": 24})
plt.show()

# %%
colors= ["purple","green","#CFC60E","0FBBAE"]
sns.set_style("whitegrid")
plt.figure(figsize=(3,5))
plt.yticks(np.arange(0,100,10))
plt.ylabel("Accuracy %")
plt.xlabel("Algorithms")
sns.barplot(x=list(accuracies.keys()),y=list(accuracies.values()),palette=colors)
plt.show()

# %%
X_test.T
# Out:
#              id  loan_amnt  funded_amnt  funded_amnt_inv  term_months  \
# 1091  1475488.0     2200.0       2200.0           2200.0         36.0
# 2194  1476705.0    14400.0      14400.0          14400.0         60.0
# 2921  1477530.0    27000.0      27000.0          27000.0         36.0
# 878   1475264.0    10000.0      10000.0          10000.0         36.0
# 3093  1477720.0    24000.0      24000.0          24000.0         36.0
# ...         ...        ...          ...              ...          ...
# 1330  1475759.0    40000.0      40000.0          40000.0         36.0
# 7056  1482099.0     1250.0       1250.0           1250.0         36.0
# 4934  1479759.0    35000.0      35000.0          35000.0         60.0
# 6662  1481671.0     8000.0       8000.0           8000.0         36.0
# 1633  1476084.0    35000.0      35000.0          35000.0         60.0
#
#       int_rate  installment  emp_length  home_ownership  annual_inc  ...  \
# ...

# %%
rf
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=12)

# %%
predictions[0:80]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-94b7715e605a> in <module>
# ----> 1 predictions[0:80]
#
# NameError: name 'predictions' is not defined

# %%
print("LOGISTIC REGRESSION")
print("\nConfusion Matrix:")
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(Y_test,Y_head_lr))
print("\n")
print(classification_report(Y_test,Y_head_lr))
print("\nThe Accuracy of Logistic Regression :")
print(accuracy_score(Y_test, Y_head_lr))
